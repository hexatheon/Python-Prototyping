# %%
from proxent_config.reader import ReportRunConfig
rr_file = "../proxent_report.json"
rr_config = ReportRunConfig(rr_file)

# %%
import warnings

import matplotlib.pyplot as plt
from proxent_reports.cme.top_and_fifo_fills import CmeTopAndFifoFillsAnalysisReport

from IPython.display import set_matplotlib_formats, Latex

# %%
plt.style.use("ggplot")
plt.rcParams['figure.autolayout'] = False

plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = "serif"
plt.rcParams['font.serif'] = "cm"
plt.rcParams['text.latex.preamble'] = "\usepackage{subdepth}, \usepackage{type1cm}"

# %matplotlib inline

pd.options.display.notebook_repr_html = True
pd.options.display.float_format = lambda x: '{:,.2f}'.format(x)

warnings.filterwarnings('ignore')

# %config InlineBackend.figure_format = rr_config.matplotlib_format

# %%
config_file = rr_config.proxent_config

# %%
trade_date = rr_config.start_date

# %%
report = CmeTopAndFifoFillsAnalysisReport(config_file=config_file, trade_date=trade_date)

# %% [markdown]
# # P/L Analysis

# %% [markdown]
# ## Outrights

# %%
report.plot_distribution(category="outrights", weighted=False)
report.plot_distribution(category="outrights", weighted=True)

# %% [markdown]
# ## Calendars

# %%
report.plot_distribution(category="calendars", weighted=False)
report.plot_distribution(category="calendars", weighted=True)
